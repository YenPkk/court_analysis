# %%
import requests as req
from bs4 import BeautifulSoup as bs
from pprint import pprint

# %%
# 搜尋"中華民國刑法 第 271 條"，的結果
url = 'https://judgment.judicial.gov.tw/FJUD/Default_AD.aspx'
res = req.get(url)
soup = bs(res.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW">
# <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="NO-CACHE" http-equiv="CACHE-CONTROL"/><meta content="https://judgment.judicial.gov.tw/fblogo.png" property="og:image"/><meta content="umNKShwdiOvOMfKadKfaFm-XU31CsqDXMNS7wbbX_ko" name="google-site-verification"/><title>
# 	裁判書查詢
# </title>
# <!--[if lt IE 9]><script src="/js/html5shiv.min.js?20240430025130965"></script><![endif]-->
# <link href="/css/bootstrap.min.css?20240430025130965" rel="stylesheet"/>
# <link href="/css/font-awesome.min.css?20240430025130965" rel="stylesheet"/>
# <link href="/css/jquery.fancybox.css?20240430025130965" media="screen" rel="stylesheet"/>
# <link href="/css/layout.css?20240430025130965" rel="stylesheet"/>
# <link href="/css/tinybox.css?20240430025130965" rel="stylesheet"/>
# <script src="/js/jquery-3.6.0.min.js?20240430025130965" type="text/javascript"></script>
# ...
