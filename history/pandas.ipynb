# %%
import pandas as pd

# %%
tt = pd.read_csv('./cases_500_v4.csv')

# %%
for a in tt['laws']:
    print(a)
# Out:
# ['刑事訴訟法 第 1、158.4、159.5、163.2、299 條（106.11.16）', '中華民國刑法 第 1、2、19、25、38、271 條（105.11.30）']
# ['槍砲彈藥刀械管制條例 第 7、12 條（106.06.14）', '中華民國刑法 第 1、25、38、47、55、57、59、164、271 條（105.11.30）', '中華民國憲法 第 1、8、23 條（36.01.01）', '刑事訴訟法 第 154、301、368、369、377 條（106.11.16）', '刑事妥速審判法 第 9 條（103.06.04）']
# ['刑事訴訟法 第 159.1、369 條（106.11.16）', '中華民國刑法 第 1、13、25、38、62、95、271 條（105.11.30）']
# ['刑事訴訟法 第 348、369 條（106.11.16）', '中華民國刑法 第 1、19、25、271 條（105.11.30）']
# ['刑事訴訟法 第 159、159.4、159.5、348、369 條（106.11.16）', '中華民國刑法 第 2、19、38.2、47、271 條（105.11.30）']
# ['家庭暴力防治法 第 2、3 條（104.02.04）', '兒童及少年福利與權益保障法 第 69、112 條（104.12.16）', '刑事訴訟法 第 159.1、159.5、299 條（106.11.16）', '中華民國刑法 第 1、25、55、57、59、271 條（105.11.30）']
# ['刑事訴訟法 第 158.4、159.5、369、371 條（106.11.16）', '中華民國刑法 第 1、2、13、25、28、38、55、59、150、271 條（105.11.30）']
# ...

# %%
for i in tt['laws']:
    if i == '[]':
        print(i)
